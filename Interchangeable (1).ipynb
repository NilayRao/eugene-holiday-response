# %%
import pandas as pd

# %% [markdown]
# # Read and Merge All the Data

# %%
init = pd.read_csv('call_data_from_CAD.csv')
init
# Out:
#          Unnamed: 0          IncidentNumber Call_Created_Time  \
# 0                 1  OR-2016-01-01-16000001       1/1/16 0:00
# 1                 2  OR-2016-01-01-16000001       1/1/16 0:00
# 2                 3  OR-2016-01-01-16000001       1/1/16 0:00
# 3                 4  OR-2016-01-01-16000003       1/1/16 0:00
# 4                 5  OR-2016-01-01-16000004       1/1/16 0:02
# ...             ...                     ...               ...
# 1048570     1048571  OR-2019-08-22-19218648     8/22/19 17:54
# 1048571     1048572  OR-2019-08-22-19218648     8/22/19 17:54
# 1048572     1048573  OR-2019-08-22-19218649     8/22/19 17:56
# 1048573     1048574  OR-2019-08-22-19218652     8/22/19 17:58
# 1048574     1048575  OR-2019-08-22-19218653     8/22/19 18:01
#
#         Call_First_Dispatched_Time Call_First_On_Scene   Call_Cleared  \
# 0                      1/1/16 0:04         1/1/16 0:09    1/1/16 0:54
# 1                      1/1/16 0:04         1/1/16 0:09    1/1/16 0:54
# 2                      1/1/16 0:04         1/1/16 0:09    1/1/16 0:54
# 3                      1/1/16 0:00         1/1/16 0:00    1/1/16 0:02
# 4                      1/1/16 0:04         1/1/16 0:04    1/1/16 0:18
# ...                            ...                 ...            ...
# 1048570              8/22/19 18:00       8/22/19 18:04  8/22/19 18:21
# 1048571              8/22/19 18:00       8/22/19 18:04  8/22/19 18:21
# 1048572                        NaN                 NaN            NaN
# 1048573              8/22/19 18:03       8/22/19 18:03  8/22/19 18:24
# 1048574                        NaN                 NaN            NaN
#
#          Call_Zipcode  Beat Call_Source Call_Priority  \
# 0             97402.0  EP05        E911             3
# 1             97402.0  EP05        E911             3
# 2             97402.0  EP05        E911             3
# 3             97401.0  EP02        SELF             6
# 4             97401.0  EP02        E911             3
# ...               ...   ...         ...           ...
# 1048570       97404.0  EP06       PHONE             3
# 1048571       97404.0  EP06       PHONE             3
# 1048572       97402.0  EP05       PHONE             P
# 1048573       97402.0  EP05       PHONE             1
# 1048574       97402.0  EP04        W911             3
#
#         InitialIncidentTypeDescription  IsPrimary PrimaryUnitCallSign  \
# 0                              ASSAULT          1                5E57
# 1                              ASSAULT          0                5E57
# 2                              ASSAULT          0                5E57
# 3                         TRAFFIC STOP          1                5T81
# 4                        CHECK WELFARE          0                3X90
# ...                                ...        ...                 ...
# 1048570            UNATTENDED CHILDREN          0                4U51
# 1048571            UNATTENDED CHILDREN          1                4U51
# 1048572                          THEFT          0                 NaN
# 1048573      MOTOR VEH ACC UNKNOWN INJ          1                3E71
# 1048574              CRIMINAL TRESPASS          0                 NaN
#
#         RespondingUnitCallSign Unit_Dispatched_Time Unit_OnScene_Time  \
# 0                         5E57          1/1/16 0:04       1/1/16 0:09
# 1                         4X40          1/1/16 0:09       1/1/16 0:09
# 2                         4E53          1/1/16 0:04       1/1/16 0:12
# 3                         5T81          1/1/16 0:00       1/1/16 0:00
# 4                         3F61          1/1/16 0:04               NaN
# ...                        ...                  ...               ...
# 1048570                   3K98        8/22/19 18:00     8/22/19 18:04
# 1048571                   4U51        8/22/19 18:00     8/22/19 18:09
# 1048572                    NaN                  NaN               NaN
# 1048573                   3E71        8/22/19 18:03     8/22/19 18:03
# 1048574                    NaN                  NaN               NaN
#
#         Unit_Cleared_Time   Disposition
# 0             1/1/16 0:54       ADVISED
# 1             1/1/16 0:46       ADVISED
# 2             1/1/16 0:51       ADVISED
# 3             1/1/16 0:02       ADVISED
# 4             1/1/16 0:08      ASSISTED
# ...                   ...           ...
# 1048570     8/22/19 18:16  PATROL CHECK
# 1048571     8/22/19 18:21  PATROL CHECK
# 1048572               NaN  REPORT TAKEN
# 1048573     8/22/19 18:24      ASSISTED
# 1048574               NaN      RESOLVED
#
# [1048575 rows x 18 columns]

# %%
import pandas as pd

# List of years to load
years = range(2014, 2026)

# Folder where the files are stored
folder = "time/"

# Load and combine all files
new2 = []
for year in years:
    path = f"{folder}class_data_{year}.csv"
    df_year = pd.read_csv(path, low_memory=False)
    df_year['year'] = year  # optional: add a year column
    new2.append(df_year)

# Concatenate all dataframes
classdata = pd.concat(new2, ignore_index=True)
classdata
# Out:
#            yr service   inci_id                 calltime  case_id callsource  \
# 0        2014    LAW   14000001  2014-01-01 00:00:05.000      NaN       SELF
# 1        2014    LAW   14000003  2014-01-01 00:01:50.000      NaN       SELF
# 2        2014    LAW   14000006  2014-01-01 00:05:17.000      NaN      PHONE
# 3        2014    LAW   14000007  2014-01-01 00:08:36.000      NaN       SELF
# 4        2014    LAW   14000011  2014-01-01 00:10:21.000      NaN       E911
# ...       ...     ...       ...                      ...      ...        ...
# 1488572  2025    LAW   25103164  2025-04-22 23:34:57.000      NaN       W911
# 1488573  2025    LAW   25103169  2025-04-22 23:48:35.000      NaN       W911
# 1488574  2025    LAW   25103175  2025-04-22 23:51:33.000  2506437       W911
# 1488575  2025    LAW   25103180  2025-04-22 23:59:31.000      NaN      PHONE
# 1488576  2025    LAW   25103312  2025-04-18 11:12:00.000  2506445       RPTO
#
#                             nature closecode                        closed_as  \
# 0                     TRAFFIC STOP      UTC   UNIFORM TRAFFIC CITATION ISSUED
# 1                     TRAFFIC STOP      ADVI                          ADVISED
# 2                          DISPUTE      ADVI                          ADVISED
# 3                     TRAFFIC STOP      WARN                          WARNING
# 4                            THEFT      RSLV                         RESOLVED
# ...                            ...       ...                              ...
# 1488572  GAS LEAK, LARGE STRUCTURE      INFO                 INFORMATION ONLY
# 1488573           BEAT INFORMATION      INFO                 INFORMATION ONLY
# 1488574             TRASH BIN FIRE      REPT                     REPORT TAKEN
# 1488575              CHECK WELFARE      REL          REFERRED TO OTHER AGENCY
# 1488576                   BURGLARY      REPT                     REPORT TAKEN
#
#          secs_to_disp  ...  secs_to_close  disp  arrv  beat priority    zip  \
# 0                 1.0  ...            690     1     1  EP05        6  97402
# 1                 0.0  ...            170     1     1  EP02        6  97401
# 2               219.0  ...           1444     1     1  EP01        3  97401
# 3                 0.0  ...            427     1     1  EP02        6  97401
# 4               168.0  ...           1126     1     1  EP05        3  97402
# ...               ...  ...            ...   ...   ...   ...      ...    ...
# 1488572           NaN  ...           1246     0     0  EP07        P  97401
# 1488573        2826.0  ...           2828     1     0  EP02        5  97401
# 1488574         412.0  ...           2249     1     0  EP05        P  97402
# 1488575           NaN  ...           1649     0     0  EP02        3  97401
# 1488576           NaN  ...              0     0     0  EP05        P  97402
#
#         primeunit units_dispd  units_arrived  year
# 0          5Z51             1              1  2014
# 1          5T82             2              2  2014
# 2          5E93             3              2  2014
# 3          5E31             2              2  2014
# 4          6E45             2              2  2014
# ...           ...         ...            ...   ...
# 1488572       NaN           0              0  2025
# 1488573    6E31             1              1  2025
# 1488574    6E64             1              1  2025
# 1488575       NaN           0              0  2025
# 1488576       NaN           0              0  2025
#
# [1488577 rows x 21 columns]

# %%
df = pd.read_csv('alldata.csv', low_memory = False)
df.head()
# Out:
#      yr service   inci_id                 calltime case_id callsource  \
# 0  2014    LAW   14000001  2014-01-01 00:00:05.000     NaN       SELF
# 1  2014    LAW   14000003  2014-01-01 00:01:50.000     NaN       SELF
# 2  2014    LAW   14000006  2014-01-01 00:05:17.000     NaN      PHONE
# 3  2014    LAW   14000007  2014-01-01 00:08:36.000     NaN       SELF
# 4  2014    LAW   14000011  2014-01-01 00:10:21.000     NaN       E911
#
#          nature closecode                        closed_as  secs_to_disp  ...  \
# 0  TRAFFIC STOP      UTC   UNIFORM TRAFFIC CITATION ISSUED           1.0  ...
# 1  TRAFFIC STOP      ADVI                          ADVISED           0.0  ...
# 2       DISPUTE      ADVI                          ADVISED         219.0  ...
# 3  TRAFFIC STOP      WARN                          WARNING           0.0  ...
# 4         THEFT      RSLV                         RESOLVED         168.0  ...
#
#    secs_to_close  disp  arrv  beat priority    zip primeunit units_dispd  \
# 0            690     1     1  EP05        6  97402    5Z51             1
# 1            170     1     1  EP02        6  97401    5T82             2
# 2           1444     1     1  EP01        3  97401    5E93             3
# 3            427     1     1  EP02        6  97401    5E31             2
# 4           1126     1     1  EP05        3  97402    6E45             2
#
#    units_arrived  year
# 0              1  2014
# 1              2  2014
# 2              2  2014
# 3              2  2014
# 4              2  2014
#
# [5 rows x 21 columns]

# %% [markdown]
# # Convert dates to datetime and make holiday columns

# %%
import pandas as pd
import holidays

# Ensure datetime format
df['calltime'] = pd.to_datetime(df['calltime'])

# Create a 'date_only' column with just the date
df['date_only'] = df['calltime'].dt.date

# Rebuild the holidays map with proper years
us_holidays = holidays.US(years=range(df['date_only'].min().year, df['date_only'].max().year + 1))

# Map holidays to the new 'date_only' column
df['holiday_name'] = df['date_only'].map(us_holidays)
df['is_holiday'] = df['holiday_name'].notna().astype(int)
df
# Out:
#            yr service   inci_id            calltime  case_id callsource  \
# 0        2014    LAW   14000001 2014-01-01 00:00:05      NaN       SELF
# 1        2014    LAW   14000003 2014-01-01 00:01:50      NaN       SELF
# 2        2014    LAW   14000006 2014-01-01 00:05:17      NaN      PHONE
# 3        2014    LAW   14000007 2014-01-01 00:08:36      NaN       SELF
# 4        2014    LAW   14000011 2014-01-01 00:10:21      NaN       E911
# ...       ...     ...       ...                 ...      ...        ...
# 1488572  2025    LAW   25103164 2025-04-22 23:34:57      NaN       W911
# 1488573  2025    LAW   25103169 2025-04-22 23:48:35      NaN       W911
# 1488574  2025    LAW   25103175 2025-04-22 23:51:33  2506437       W911
# 1488575  2025    LAW   25103180 2025-04-22 23:59:31      NaN      PHONE
# 1488576  2025    LAW   25103312 2025-04-18 11:12:00  2506445       RPTO
#
#                             nature closecode                        closed_as  \
# 0                     TRAFFIC STOP      UTC   UNIFORM TRAFFIC CITATION ISSUED
# 1                     TRAFFIC STOP      ADVI                          ADVISED
# 2                          DISPUTE      ADVI                          ADVISED
# 3                     TRAFFIC STOP      WARN                          WARNING
# 4                            THEFT      RSLV                         RESOLVED
# ...                            ...       ...                              ...
# 1488572  GAS LEAK, LARGE STRUCTURE      INFO                 INFORMATION ONLY
# 1488573           BEAT INFORMATION      INFO                 INFORMATION ONLY
# 1488574             TRASH BIN FIRE      REPT                     REPORT TAKEN
# 1488575              CHECK WELFARE      REL          REFERRED TO OTHER AGENCY
# 1488576                   BURGLARY      REPT                     REPORT TAKEN
#
#          secs_to_disp  ...  beat  priority    zip  primeunit units_dispd  \
# 0                 1.0  ...  EP05         6  97402     5Z51             1
# 1                 0.0  ...  EP02         6  97401     5T82             2
# 2               219.0  ...  EP01         3  97401     5E93             3
# 3                 0.0  ...  EP02         6  97401     5E31             2
# 4               168.0  ...  EP05         3  97402     6E45             2
# ...               ...  ...   ...       ...    ...        ...         ...
# 1488572           NaN  ...  EP07         P  97401        NaN           0
# 1488573        2826.0  ...  EP02         5  97401     6E31             1
# 1488574         412.0  ...  EP05         P  97402     6E64             1
# 1488575           NaN  ...  EP02         3  97401        NaN           0
# 1488576           NaN  ...  EP05         P  97402        NaN           0
#
#         units_arrived  year   date_only    holiday_name  is_holiday
# 0                   1  2014  2014-01-01  New Year's Day           1
# 1                   2  2014  2014-01-01  New Year's Day           1
# 2                   2  2014  2014-01-01  New Year's Day           1
# 3                   2  2014  2014-01-01  New Year's Day           1
# 4                   2  2014  2014-01-01  New Year's Day           1
# ...               ...   ...         ...             ...         ...
# 1488572             0  2025  2025-04-22             NaN           0
# 1488573             1  2025  2025-04-22             NaN           0
# 1488574             1  2025  2025-04-22             NaN           0
# 1488575             0  2025  2025-04-22             NaN           0
# 1488576             0  2025  2025-04-18             NaN           0
#
# [1488577 rows x 24 columns]

# %% [markdown]
# # Create new dataframe including all the calls relating to cahoots

# %%
df_cahoots = df[df['primeunit'] == 'CAHOOT'].reset_index(drop=True)
df_cahoots
# Out:
#           yr service   inci_id            calltime case_id callsource  \
# 0       2014    LAW   14000107 2014-01-01 01:55:39     NaN      PHONE
# 1       2014    LAW   14000382 2014-01-01 12:50:34     NaN      PHONE
# 2       2014    LAW   14000408 2014-01-01 13:29:17     NaN      PHONE
# 3       2014    LAW   14000414 2014-01-01 13:37:12     NaN      PHONE
# 4       2014    LAW   14000416 2014-01-01 13:38:38     NaN      PHONE
# ...      ...     ...       ...                 ...     ...        ...
# 182576  2025    OTHR  25088809 2025-04-07 02:16:27     NaN       W911
# 182577  2025    OTHR  25088831 2025-04-07 02:54:53     NaN      PHONE
# 182578  2025    OTHR  25088848 2025-04-07 03:21:06     NaN      PHONE
# 182579  2025    OTHR  25088860 2025-04-07 03:49:10     NaN      PHONE
# 182580  2025    OTHR  25088867 2025-04-07 04:33:08     NaN      PHONE
#
#                            nature closecode         closed_as  secs_to_disp  \
# 0                       TRANSPORT      TRAN    TRANSPORT MADE        1213.0
# 1                       TRANSPORT      ASST          ASSISTED         396.0
# 2                       TRANSPORT      ASST          ASSISTED         505.0
# 3                   CHECK WELFARE      DIS          DISREGARD           NaN
# 4                    SUBJECT DOWN      ASST          ASSISTED          36.0
# ...                           ...       ...               ...           ...
# 182576     PUBLIC ASSIST, CAHOOTS      INFO  INFORMATION ONLY           NaN
# 182577     PUBLIC ASSIST, CAHOOTS      ASST          ASSISTED         727.0
# 182578     PUBLIC ASSIST, CAHOOTS      ASST          ASSISTED         590.0
# 182579     PUBLIC ASSIST, CAHOOTS      ASST          ASSISTED        1100.0
# 182580  SUICIDAL SUBJECT, CAHOOTS      UTL   UNABLE TO LOCATE          19.0
#
#         ...  beat  priority    zip  primeunit units_dispd units_arrived  year  \
# 0       ...  EP02         5  97401     CAHOOT           1             1  2014
# 1       ...  EP02         5  97401     CAHOOT           1             1  2014
# 2       ...  EP05         5  97402     CAHOOT           1             1  2014
# 3       ...  EP01         5  97401     CAHOOT           0             0  2014
# 4       ...  EP05         1  97402     CAHOOT           1             1  2014
# ...     ...   ...       ...    ...        ...         ...           ...   ...
# 182576  ...  EP05         7  97402     CAHOOT           0             0  2025
# 182577  ...  EP02         7  97401     CAHOOT           1             1  2025
# 182578  ...  EP02         5  97401     CAHOOT           1             1  2025
# 182579  ...  EP01         5  97401     CAHOOT           1             1  2025
# 182580  ...  EP01         5  97401     CAHOOT           1             1  2025
#
#          date_only    holiday_name  is_holiday
# 0       2014-01-01  New Year's Day           1
# 1       2014-01-01  New Year's Day           1
# 2       2014-01-01  New Year's Day           1
# 3       2014-01-01  New Year's Day           1
# 4       2014-01-01  New Year's Day           1
# ...            ...             ...         ...
# 182576  2025-04-07             NaN           0
# 182577  2025-04-07             NaN           0
# 182578  2025-04-07             NaN           0
# 182579  2025-04-07             NaN           0
# 182580  2025-04-07             NaN           0
#
# [182581 rows x 24 columns]

# %% [markdown]
# # Everything Except Cahoots in this Dataframe

# %%
not_df = df[df['primeunit'] != 'CAHOOT'].reset_index(drop=True)
not_df
# Out:
#            yr service   inci_id            calltime  case_id callsource  \
# 0        2014    LAW   14000001 2014-01-01 00:00:05      NaN       SELF
# 1        2014    LAW   14000003 2014-01-01 00:01:50      NaN       SELF
# 2        2014    LAW   14000006 2014-01-01 00:05:17      NaN      PHONE
# 3        2014    LAW   14000007 2014-01-01 00:08:36      NaN       SELF
# 4        2014    LAW   14000011 2014-01-01 00:10:21      NaN       E911
# ...       ...     ...       ...                 ...      ...        ...
# 1305991  2025    LAW   25103164 2025-04-22 23:34:57      NaN       W911
# 1305992  2025    LAW   25103169 2025-04-22 23:48:35      NaN       W911
# 1305993  2025    LAW   25103175 2025-04-22 23:51:33  2506437       W911
# 1305994  2025    LAW   25103180 2025-04-22 23:59:31      NaN      PHONE
# 1305995  2025    LAW   25103312 2025-04-18 11:12:00  2506445       RPTO
#
#                             nature closecode                        closed_as  \
# 0                     TRAFFIC STOP      UTC   UNIFORM TRAFFIC CITATION ISSUED
# 1                     TRAFFIC STOP      ADVI                          ADVISED
# 2                          DISPUTE      ADVI                          ADVISED
# 3                     TRAFFIC STOP      WARN                          WARNING
# 4                            THEFT      RSLV                         RESOLVED
# ...                            ...       ...                              ...
# 1305991  GAS LEAK, LARGE STRUCTURE      INFO                 INFORMATION ONLY
# 1305992           BEAT INFORMATION      INFO                 INFORMATION ONLY
# 1305993             TRASH BIN FIRE      REPT                     REPORT TAKEN
# 1305994              CHECK WELFARE      REL          REFERRED TO OTHER AGENCY
# 1305995                   BURGLARY      REPT                     REPORT TAKEN
#
#          secs_to_disp  ...  beat  priority    zip  primeunit units_dispd  \
# 0                 1.0  ...  EP05         6  97402     5Z51             1
# 1                 0.0  ...  EP02         6  97401     5T82             2
# 2               219.0  ...  EP01         3  97401     5E93             3
# 3                 0.0  ...  EP02         6  97401     5E31             2
# 4               168.0  ...  EP05         3  97402     6E45             2
# ...               ...  ...   ...       ...    ...        ...         ...
# 1305991           NaN  ...  EP07         P  97401        NaN           0
# 1305992        2826.0  ...  EP02         5  97401     6E31             1
# 1305993         412.0  ...  EP05         P  97402     6E64             1
# 1305994           NaN  ...  EP02         3  97401        NaN           0
# 1305995           NaN  ...  EP05         P  97402        NaN           0
#
#         units_arrived  year   date_only    holiday_name  is_holiday
# 0                   1  2014  2014-01-01  New Year's Day           1
# 1                   2  2014  2014-01-01  New Year's Day           1
# 2                   2  2014  2014-01-01  New Year's Day           1
# 3                   2  2014  2014-01-01  New Year's Day           1
# 4                   2  2014  2014-01-01  New Year's Day           1
# ...               ...   ...         ...             ...         ...
# 1305991             0  2025  2025-04-22             NaN           0
# 1305992             1  2025  2025-04-22             NaN           0
# 1305993             1  2025  2025-04-22             NaN           0
# 1305994             0  2025  2025-04-22             NaN           0
# 1305995             0  2025  2025-04-18             NaN           0
#
# [1305996 rows x 24 columns]

# %% [markdown]
# # Base Data Cleaning and Initial Analytics

# %%
df.columns.to_list()
# Keep only rows with non-negative response times
df_cahoots = df[df['secs_to_arrv'] >= 0]

# %%
df_cahoots.groupby('is_holiday')['secs_to_arrv'].describe()
# Out:
#                count         mean          std      min      25%     50%  \
# is_holiday
# 0           136972.0  5936.827308  8717.733032 -84840.0  1207.00  2938.0
# 1             4592.0  5359.692073  7730.918302      0.0  1141.25  2633.5
#
#                75%       max
# is_holiday
# 0           7276.0  424459.0
# 1           6503.5  102212.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='is_holiday', y='secs_to_arrv', data=df_cahoots)
plt.xticks([0, 1], ['Non-Holiday', 'Holiday'])
plt.ylabel('Seconds to Arrive')
plt.title('Response Time on Holidays vs. Non-Holidays')
plt.show()

# %%
daily = df_cahoots.groupby('date_only')['secs_to_arrv'].mean().reset_index()

plt.figure(figsize=(12, 5))
plt.plot(daily['date_only'], daily['secs_to_arrv'])
plt.title('Daily Average Response Time Over Time')
plt.xlabel('Date')
plt.ylabel('Avg Seconds to Arrive')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Initial T-test

# %%
from scipy.stats import ttest_ind

# Optionally drop NaNs or negative response times if not already done
holiday_times = df_cahoots[df_cahoots['is_holiday'] == 1]['secs_to_arrv'].dropna()
nonholiday_times = df_cahoots[df_cahoots['is_holiday'] == 0]['secs_to_arrv'].dropna()

# T-test: unequal variance (Welch’s t-test is safer for unequal sample sizes)
t_stat, p_val = ttest_ind(holiday_times, nonholiday_times, equal_var=False)

print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_val:.5f}")

if p_val < 0.05:
    print("Result: Statistically significant difference in response times.")
else:
    print("Result: No statistically significant difference.")
# Out:
# T-statistic: -4.954
# P-value: 0.00000
# Result: Statistically significant difference in response times.

# %%
# Full data remains untouched so just making a copy
df_all = df.copy()

# Cleaned version (exclude 0 and negative response times)
df_rt = df[df['secs_to_arrv'] > 0].copy()

# %%
# Group by day and count calls
daily_counts = df_cahoots.groupby(['date_only', 'is_holiday']).size().reset_index(name='call_volume')
holiday_volumes = daily_counts[daily_counts['is_holiday'] == 1]['call_volume']
nonholiday_volumes = daily_counts[daily_counts['is_holiday'] == 0]['call_volume']
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.hist(nonholiday_volumes, bins=50, alpha=0.5, density=True, label='Non-Holiday', color='blue')
plt.hist(holiday_volumes, bins=50, alpha=0.5, density=True, label='Holiday', color='green')

plt.xlabel('Calls per Day')
plt.ylabel('Density')
plt.title('Daily 911 Call Volume: Holiday vs. Non-Holiday')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Smooth and Normalize graph from above

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# KDE plot
sns.kdeplot(nonholiday_volumes, label='Non-Holiday', fill=True, color='darkorange', alpha=0.3, bw_adjust=1.2)
sns.kdeplot(holiday_volumes, label='Holiday', fill=True, color='royalblue', alpha=0.3, bw_adjust=1.2)

plt.text(0.02, 0.60,
         f"T-test:\nT = {t_stat:.2f}\nP = {p_val:.5f}",
         transform=plt.gca().transAxes,
         fontsize=16, color='black', va='top')
plt.xlabel('Incidents per Day')
plt.ylabel('Density')
plt.title('Smoothed Daily 911 Incident Volume: Holiday vs. Non-Holiday')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Ensure calltime is datetime
df_cahoots['calltime'] = pd.to_datetime(df_cahoots['calltime'], errors='coerce')

# Create date-only column for grouping
df_cahoots['date_only'] = df_cahoots['calltime'].dt.date

# %% [markdown]
# ## Incidents per day by each holiday

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind

# Define main holidays to compare
main_holidays = ["New Year's Day", 'Martin Luther King Jr. Day',
       "Washington's Birthday", 'Memorial Day', 'Independence Day',
       'Labor Day', 'Columbus Day', 'Veterans Day', 'Thanksgiving Day',
       'Christmas Day', 'Independence Day (observed)',
       'Christmas Day (observed)', "New Year's Day (observed)",
       'Veterans Day (observed)',
       'Juneteenth National Independence Day (observed)',
       'Juneteenth National Independence Day']

# Prepare subplot grid
fig, axes = plt.subplots(nrows=8, ncols=2, figsize=(14, 50))
axes = axes.flatten()
df_all['date_only'] = pd.to_datetime(df_all['date_only'])
# Loop through holidays
for i, holiday in enumerate(main_holidays):
    ax = axes[i]

    # Identify the holiday's call dates
    holiday_days = df_all[df_all['holiday_name'] == holiday]['date_only'].unique()

    # Daily call volumes for the holiday
    holiday_volumes = df_all[df_all['date_only'].isin(holiday_days)].groupby('date_only').size()

    # For comparison: non-holiday days from the same month(s)
    holiday_months = pd.to_datetime(holiday_days).month
    nonholiday_days = df_all[
        df_all['date_only'].dt.month.isin(holiday_months) &
        (~df_all['date_only'].isin(holiday_days))
    ]
    nonholiday_volumes = nonholiday_days.groupby('date_only').size()

    # KDE plots
    if not nonholiday_volumes.empty:
        sns.kdeplot(nonholiday_volumes, label='Non-Holiday', fill=True, color='darkorange', alpha=0.3, ax=ax)
    if not holiday_volumes.empty:
        sns.kdeplot(holiday_volumes, label='Holiday', fill=True, color='royalblue', alpha=0.3, ax=ax)

    # T-test
    if len(holiday_volumes) > 1 and len(nonholiday_volumes) > 1:
        t_stat, p_val = ttest_ind(holiday_volumes, nonholiday_volumes, equal_var=False)
    else:
        t_stat, p_val = float('nan'), float('nan')

    # Add stats annotation
    ax.set_title(f"{holiday}")
    ax.set_xlabel('Incidents per Day')
    ax.set_ylabel('Density')
    ax.text(0.05, 0.95, f"T = {t_stat:.2f}\nP = {p_val:.4f}",
            transform=ax.transAxes,
            fontsize=14,
            verticalalignment='top',
            bbox=dict(facecolor='white', edgecolor='gray', boxstyle='round,pad=0.2'))

# Layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Filter out zero/negative response times
df_rt = df_cahoots[df_cahoots['secs_to_arrv'] > 0].copy()

# Get top 10 'nature' types
top_natures = df_rt['nature'].value_counts().head(10).index.tolist()

# Filter only those top 10 types
df_top = df_rt[df_rt['nature'].isin(top_natures)]

# Group by call type and holiday status
grouped = df_top.groupby(['nature', 'is_holiday'])['secs_to_arrv'].mean().reset_index()

# Convert holiday flag to label
grouped['is_holiday'] = grouped['is_holiday'].map({0: 'Non-Holiday', 1: 'Holiday'})

# Sort by overall mean for visual consistency
order = df_top.groupby('nature')['secs_to_arrv'].mean().sort_values(ascending=False).index.tolist()

# Plot
plt.figure(figsize=(14, 7))
sns.barplot(data=grouped, x='nature', y='secs_to_arrv', hue='is_holiday', order=order, palette=['darkorange', 'royalblue'])

plt.xticks(rotation=45, ha='right')
plt.xlabel('Call Type (Nature)')
plt.ylabel('Avg Seconds to Arrive')
plt.title('Average Response Time by Call Type: Holiday vs. Non-Holiday')
plt.legend(title='Day Type')
plt.tight_layout()
plt.show()

# %%
# Top 10 call types
top_natures = df_cahoots['nature'].value_counts().head(10).index.tolist()
df_top = df_cahoots[df_cahoots['nature'].isin(top_natures)]

# Count total calls by holiday type (for denominator)
total_by_daytype = df_top.groupby('is_holiday').size()

# Count calls per type per holiday type
call_counts = df_top.groupby(['nature', 'is_holiday']).size().reset_index(name='count')

# Convert to percentage of total for each day type
call_counts['percent'] = call_counts.apply(
    lambda row: (row['count'] / total_by_daytype[row['is_holiday']]) * 100,
    axis=1
)

# Convert labels
call_counts['is_holiday'] = call_counts['is_holiday'].map({0: 'Non-Holiday', 1: 'Holiday'})

# Sort by non-holiday volume (to order x-axis consistently)
order = df_top[df_top['is_holiday'] == 0]['nature'].value_counts().loc[top_natures].index.tolist()

# Plot
plt.figure(figsize=(14, 7))
sns.barplot(data=call_counts, x='nature', y='percent', hue='is_holiday',
            order=order, palette=['darkorange', 'royalblue'])

plt.title("Percentage of Incidents by Type: Holiday vs. Non-Holiday")
plt.xlabel("Incident Type (Nature)")
plt.ylabel("Percent of Total Incidents")
plt.xticks(rotation=45, ha='right')
plt.legend(title='Day Type')
plt.tight_layout()
plt.show()

# %%
df_close = df_cahoots[df_cahoots['secs_to_close'] > 0].copy()
from scipy.stats import ttest_ind

holiday_close = df_close[df_close['is_holiday'] == 1]['secs_to_close']
nonholiday_close = df_close[df_close['is_holiday'] == 0]['secs_to_close']

t_stat, p_val = ttest_ind(holiday_close, nonholiday_close, equal_var=False)

print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_val:.5f}")
if p_val < 0.05:
    print("✅ Statistically significant difference in how long calls take to close.")
else:
    print("❌ No statistically significant difference.")
# Out:
# T-statistic: -3.23
# P-value: 0.00124
# ✅ Statistically significant difference in how long calls take to close.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
import seaborn as sns

# Filter top 10 incident types
top_natures = df_close['nature'].value_counts().head(10).index.tolist()
df_top = df_close[df_close['nature'].isin(top_natures)]

# Group by call type and holiday status
avg_close_by_nature = df_top.groupby(['nature', 'is_holiday'])['secs_to_close'].mean().reset_index()
avg_close_by_nature['is_holiday'] = avg_close_by_nature['is_holiday'].map({0: 'Non-Holiday', 1: 'Holiday'})

# Sort call types by overall average close time
nature_order = df_top.groupby('nature')['secs_to_close'].mean().sort_values(ascending=False).index.tolist()

# Plot
plt.figure(figsize=(14, 7))
sns.barplot(data=avg_close_by_nature, x='nature', y='secs_to_close', hue='is_holiday',
            order=order, palette=['darkorange', 'royalblue'])

plt.title("Average Incident Closure Time by Incident Type")
plt.xlabel("Incident Type (Nature)")
plt.ylabel("Seconds to Close")
plt.xticks(rotation=45, ha='right')
plt.legend(title="Day Type")
plt.tight_layout()
plt.show()

# %%
# Calculate % difference
pivot = call_counts.pivot(index='nature', columns='is_holiday', values='percent')
pivot['delta'] = pivot['Holiday'] - pivot['Non-Holiday']
pivot.sort_values(by='delta', ascending=False)
# Out:
# is_holiday                   Holiday  Non-Holiday     delta
# nature
# TRANSPORT                  18.895404    17.137261  1.758143
# TRANSPORT, CAHOOTS          3.555892     2.901786  0.654106
# PUBLIC ASSIST, CAHOOTS     12.351050    11.776938  0.574111
# SUICIDAL SUBJECT, CAHOOTS   2.837148     2.667125  0.170023
# ASSIST PD, CAHOOTS          1.361831     1.337378  0.024453
# CHECK WELFARE, CAHOOTS      9.721960     9.715227  0.006733
# INTOXICATED SUBJECT         1.588803     1.814332 -0.225529
# SUICIDAL SUBJECT            3.404577     3.973341 -0.568764
# ASSIST PUBLIC- POLICE      25.345186    25.988884 -0.643697
# CHECK WELFARE              20.938150    22.687729 -1.749579

# %%
from scipy.stats import chi2_contingency
import pandas as pd

# Filter for top 10 incident types
top_natures = df_cahoots['nature'].value_counts().head(10).index.tolist()
df_top = df_cahoots[df_cahoots['nature'].isin(top_natures)]

# Group counts
count_table = pd.crosstab(df_top['nature'], df_top['is_holiday'])

# Add column labels
count_table.columns = ['Non-Holiday', 'Holiday']

# Calculate % difference and total count difference
count_table['total_diff'] = count_table['Holiday'] - count_table['Non-Holiday']
count_table['percent_holiday'] = count_table['Holiday'] / (count_table['Holiday'] + count_table['Non-Holiday']) * 100
count_table['percent_nonholiday'] = count_table['Non-Holiday'] / (count_table['Holiday'] + count_table['Non-Holiday']) * 100
count_table['percent_diff'] = count_table['percent_holiday'] - count_table['percent_nonholiday']

# Chi-squared test across entire table
chi2, p, dof, expected = chi2_contingency(count_table.iloc[:, :2])

print(f"Chi-square statistic: {chi2:.2f}")
print(f"P-value: {p:.5f}")

# Sort and view
count_table_sorted = count_table.sort_values(by='percent_diff', ascending=False)
count_table_sorted
# Out:
# Chi-square statistic: 32.05
# P-value: 0.00020
#                            Non-Holiday  Holiday  total_diff  percent_holiday  \
# nature
# TRANSPORT, CAHOOTS                4563      188       -4375         3.957062
# TRANSPORT                        26948      999      -25949         3.574623
# SUICIDAL SUBJECT, CAHOOTS         4194      150       -4044         3.453039
# PUBLIC ASSIST, CAHOOTS           18519      653      -17866         3.406009
# ASSIST PD, CAHOOTS                2103       72       -2031         3.310345
# CHECK WELFARE, CAHOOTS           15277      514      -14763         3.255019
# ASSIST PUBLIC- POLICE            40867     1340      -39527         3.174829
# CHECK WELFARE                    35676     1107      -34569         3.009542
# INTOXICATED SUBJECT               2853       84       -2769         2.860061
# SUICIDAL SUBJECT                  6248      180       -6068         2.800249
#
#                            percent_nonholiday  percent_diff
# nature
# TRANSPORT, CAHOOTS                  96.042938    -92.085877
# TRANSPORT                           96.425377    -92.850753
# SUICIDAL SUBJECT, CAHOOTS           96.546961    -93.093923
# PUBLIC ASSIST, CAHOOTS              96.593991    -93.187982
# ASSIST PD, CAHOOTS                  96.689655    -93.379310
# CHECK WELFARE, CAHOOTS              96.744981    -93.489963
# ASSIST PUBLIC- POLICE               96.825171    -93.650342
# CHECK WELFARE                       96.990458    -93.980915
# INTOXICATED SUBJECT                 97.139939    -94.279877
# SUICIDAL SUBJECT                    97.199751    -94.399502

# %%
from scipy.stats import ttest_ind
import pandas as pd

# Filter valid response times
df_rt = df_cahoots[df_cahoots['secs_to_arrv'] > 0].copy()

# Top incident types to include
top_natures = df_rt['nature'].value_counts().head(10).index.tolist()

# Store results
response_results = []

for nature in top_natures:
    sub = df_rt[df_rt['nature'] == nature]
    holiday = sub[sub['is_holiday'] == 1]['secs_to_arrv']
    nonholiday = sub[sub['is_holiday'] == 0]['secs_to_arrv']

    if len(holiday) > 1 and len(nonholiday) > 1:
        t_stat, p_val = ttest_ind(holiday, nonholiday, equal_var=False)
        delta = holiday.mean() - nonholiday.mean()
    else:
        t_stat, p_val, delta = float('nan'), float('nan'), float('nan')

    response_results.append({
        'nature': nature,
        'mean_holiday': holiday.mean(),
        'mean_nonholiday': nonholiday.mean(),
        'delta': delta,
        't_stat': t_stat,
        'p_val': p_val
    })

# Convert to DataFrame
response_df = pd.DataFrame(response_results).sort_values(by='delta', ascending=False)
response_df
# Out:
#                       nature  mean_holiday  mean_nonholiday        delta  \
# 5           SUICIDAL SUBJECT   2563.529070      2522.572673    40.956396
# 1              CHECK WELFARE   5068.510544      5206.263118  -137.752574
# 8        INTOXICATED SUBJECT   3341.319444      3559.962281  -218.642836
# 6  SUICIDAL SUBJECT, CAHOOTS   2807.581967      3450.725304  -643.143337
# 4     CHECK WELFARE, CAHOOTS   5131.377261      5818.953940  -687.576679
# 0      ASSIST PUBLIC- POLICE   6480.074951      7267.967950  -787.893000
# 2                  TRANSPORT   5368.727642      6165.720082  -796.992440
# 3     PUBLIC ASSIST, CAHOOTS   7744.611588      8569.742215  -825.130627
# 9         ASSIST PD, CAHOOTS   1254.019231      2779.239975 -1525.220744
# 7         TRANSPORT, CAHOOTS   5606.192593      7568.415493 -1962.222900
#
#      t_stat         p_val
# 5  0.178931  8.581887e-01
# 1 -0.599594  5.489185e-01
# 8 -0.432905  6.663188e-01
# 6 -2.433233  1.616704e-02
# 4 -1.629772  1.039075e-01
# 0 -3.269366  1.111101e-03
# 2 -3.676462  2.520449e-04
# 3 -1.820558  6.926716e-02
# 9 -5.873642  7.961741e-08
# 7 -3.507989  5.928692e-04

# %%
# Filter valid close times
df_close = df_cahoots[df_cahoots['secs_to_close'] > 0].copy()

# Top types (reuse same top_natures if you want consistency)
close_results = []

for nature in top_natures:
    sub = df_close[df_close['nature'] == nature]
    holiday = sub[sub['is_holiday'] == 1]['secs_to_close']
    nonholiday = sub[sub['is_holiday'] == 0]['secs_to_close']

    if len(holiday) > 1 and len(nonholiday) > 1:
        t_stat, p_val = ttest_ind(holiday, nonholiday, equal_var=False)
        delta = holiday.mean() - nonholiday.mean()
    else:
        t_stat, p_val, delta = float('nan'), float('nan'), float('nan')

    close_results.append({
        'nature': nature,
        'mean_holiday': holiday.mean(),
        'mean_nonholiday': nonholiday.mean(),
        'delta': delta,
        't_stat': t_stat,
        'p_val': p_val
    })

# Convert to DataFrame
close_df = pd.DataFrame(close_results).sort_values(by='delta', ascending=False)
close_df
# Out:
#                       nature  mean_holiday  mean_nonholiday        delta  \
# 4     CHECK WELFARE, CAHOOTS   7862.507782      7294.272293   568.235489
# 8        INTOXICATED SUBJECT   4771.821429      4808.896600   -37.075171
# 5           SUICIDAL SUBJECT   5295.950000      5356.301313   -60.351313
# 1              CHECK WELFARE   6473.025294      6607.287124  -134.261830
# 6  SUICIDAL SUBJECT, CAHOOTS   5351.106667      5889.117338  -538.010672
# 9         ASSIST PD, CAHOOTS   4427.222222      5054.970490  -627.748268
# 2                  TRANSPORT   6802.811812      7553.783291  -750.971479
# 0      ASSIST PUBLIC- POLICE   8152.982836      8937.930012  -784.947176
# 3     PUBLIC ASSIST, CAHOOTS   9489.329250     10344.272904  -854.943654
# 7         TRANSPORT, CAHOOTS   7446.351064      9259.515457 -1813.164393
#
#      t_stat     p_val
# 4  0.751866  0.452470
# 8 -0.083450  0.933679
# 5 -0.203830  0.838691
# 1 -0.600984  0.547966
# 6 -1.309870  0.192094
# 9 -0.774163  0.441241
# 2 -3.871823  0.000114
# 0 -3.486079  0.000505
# 3 -2.109225  0.035278
# 7 -3.416185  0.000762

# %%
from scipy.stats import ttest_ind

# Get the top 10 call types again
top_natures = df_rt['nature'].value_counts().head(10).index.tolist()

# Store results
results = []

# Loop through each call type
for nature in top_natures:
    sub = df_rt[df_rt['nature'] == nature]
    h_times = sub[sub['is_holiday'] == 1]['secs_to_arrv']
    nh_times = sub[sub['is_holiday'] == 0]['secs_to_arrv']

    if len(h_times) > 1 and len(nh_times) > 1:
        t_stat, p_val = ttest_ind(h_times, nh_times, equal_var=False)
    else:
        t_stat, p_val = float('nan'), float('nan')

    results.append({'nature': nature, 't_stat': t_stat, 'p_value': p_val})

# Create DataFrame of results
ttest_df = pd.DataFrame(results).sort_values(by='p_value')
ttest_df
# Out:
#                       nature    t_stat       p_value
# 9         ASSIST PD, CAHOOTS -5.873642  7.961741e-08
# 2                  TRANSPORT -3.676462  2.520449e-04
# 7         TRANSPORT, CAHOOTS -3.507989  5.928692e-04
# 0      ASSIST PUBLIC- POLICE -3.269366  1.111101e-03
# 6  SUICIDAL SUBJECT, CAHOOTS -2.433233  1.616704e-02
# 3     PUBLIC ASSIST, CAHOOTS -1.820558  6.926716e-02
# 4     CHECK WELFARE, CAHOOTS -1.629772  1.039075e-01
# 1              CHECK WELFARE -0.599594  5.489185e-01
# 8        INTOXICATED SUBJECT -0.432905  6.663188e-01
# 5           SUICIDAL SUBJECT  0.178931  8.581887e-01
